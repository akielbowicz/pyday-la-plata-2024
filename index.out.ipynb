# %% [markdown]
# # Manuscrito
#
# Sasha (Gremio Pythonista)
#
# # Simulación de las caminatas

# %%
from numpy.random import randint
from numpy import argmax, arange
from matplotlib.pyplot import plot, hist, scatter

# %% [markdown]
# Si tenemos una variable aleatoria $X \in \{-1,1\}$ con una distribución uniforme. Podemos simularla con:

# %%
n_pasos = 100
n_caminatas = 1 

pasos = 2*randint(0,2, (n_pasos, n_caminatas)) - 1

# %% [markdown]
# Una caminata aleatoria de largo $N$ se considera como la trayectoria que realiza una variable aleatoria
#
# <span id="eq-caminata-aleatoria">$$
# S = \sum_{i=1}^{N} X_{i}
#  \qquad(1)$$</span>

# %%
caminatas = pasos.cumsum(axis=0)
plot(caminatas)

# %% [markdown]
# Queremos estudiar cual es la probabilidad $P$ de que un caminante regrese al origen en $n$ pasos.

# %%
vuelta_al_origen = argmax(caminatas == 0, axis=0)

# %%
h = hist(vuelta_al_origen, bins=30)

# %% [markdown]
# ## Estudio del conjunto de caminatas aleatorias
#
# Por la definición de <a href="#eq-caminata-aleatoria" class="quarto-xref">Equation 1</a> podemos estudiar la esperanza y la varianza de un conjunto de caminatas

# %%
t = arange(100)
vm = caminatas.mean(axis=1)
ds = caminatas.var(axis=1)

scatter(t,vm)

# %%
scatter(t,ds)

# %% [markdown]
# Se puede observar en <a href="#fig-valor-medio" class="quarto-xref">Figure 1</a> la mayoria de las caminatas rondan el origen, y en <a href="#fig-varianza" class="quarto-xref">Figure 2</a> como la varianza crece de manera lineal.
#
# Cualquer duda consultar ([Knuth 1984](#ref-knuth84)).

# %% [markdown]
# Knuth, Donald E. 1984. “Literate Programming.” *Comput. J.* 27 (2): 97–111. <https://doi.org/10.1093/comjnl/27.2.97>.
